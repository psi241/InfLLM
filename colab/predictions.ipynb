# %% [markdown]
# # Additional Prediction Generation
# Run with A100/L4 GPU

# %%
# !git clone https://github.com/psi241/InfLLM.git
# !cd InfLLM/ && git checkout rag # https://stackoverflow.com/a/60579415 on 18 November 2025 CC BY-SA 4.0
# Out:
# Cloning into 'InfLLM'...
# remote: Enumerating objects: 467, done.
# remote: Counting objects: 100% (336/336), done.
# remote: Compressing objects: 100% (168/168), done.
# remote: Total 467 (delta 220), reused 228 (delta 165), pack-reused 131 (from 1)
# Receiving objects: 100% (467/467), 275.27 KiB | 2.15 MiB/s, done.
# Resolving deltas: 100% (297/297), done.
# Branch 'rag' set up to track remote branch 'rag' from 'origin'.
# Switched to a new branch 'rag'

# %%
# !cd InfLLM/ && git checkout rag
# !mv InfLLM/* .
# !pip install -r requirements.txt
# Out:
# Already on 'rag'
# Your branch is up to date with 'origin/rag'.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 kB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.7/137.7 kB 8.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 114.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.9/256.9 kB 26.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 48.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 119.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 797.2/797.2 kB 62.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 8.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.0/50.0 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.1/67.1 kB 6.8 MB/s eta 0:00:00
# ...

# %%
# !bash scripts/test_download.sh
# Out:
# mkdir: cannot create directory ‘benchmark/data’: File exists
# mkdir: cannot create directory ‘benchmark/data/longbench’: File exists
# The repository for THUDM/LongBench contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/THUDM/LongBench.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# Do you wish to run the custom code? [y/N] y
# data.zip: 100% 114M/114M [00:02<00:00, 49.1MB/s]
# Generating test split: 200 examples [00:00, 1018.50 examples/s]
# Saving the dataset (1/1 shards): 100% 200/200 [00:00<00:00, 13420.48 examples/s]
# Generating test split: 200 examples [00:00, 4662.85 examples/s]
# Saving the dataset (1/1 shards): 100% 200/200 [00:00<00:00, 33404.78 examples/s]
# Generating test split: 150 examples [00:00, 3679.95 examples/s]
# Saving the dataset (1/1 shards): 100% 150/150 [00:00<00:00, 24719.88 examples/s]
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir benchmark/data/longbench_extracted
# !cp -r drive/MyDrive/NLP/extracted/*.jsonl benchmark/data/longbench_extracted
# Out:
# mkdir: cannot create directory ‘benchmark/data/longbench_extracted’: File exists

# %%
# !mkdir benchmark/longbench-result

# %%
# Only run to update specific code files replacement after git push from the local repository
# !rm inf_llm/attention/origin.py
# !rm -r InfLLM/
# !git clone https://github.com/psi241/InfLLM.git
# !cd InfLLM/ && git checkout rag
# !mv InfLLM/inf_llm/attention/origin.py inf_llm/attention/
# !mv InfLLM/config/qwen-small-origin.yaml config/
# Out:
# Cloning into 'InfLLM'...
# remote: Enumerating objects: 438, done.
# remote: Counting objects: 100% (307/307), done.
# remote: Compressing objects: 100% (146/146), done.
# remote: Total 438 (delta 197), reused 215 (delta 158), pack-reused 131 (from 1)
# Receiving objects: 100% (438/438), 272.14 KiB | 13.61 MiB/s, done.
# Resolving deltas: 100% (274/274), done.
# Branch 'rag' set up to track remote branch 'rag' from 'origin'.
# Switched to a new branch 'rag'

# %%
# OLD
# !python benchmark/pred.py \
--config_path config/qwen-small.yaml \
--output_dir_path benchmark/longbench-result \
--datasets narrativeqa
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:942: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Pred narrativeqa
#   2% 4/200 [00:18<12:34,  3.85s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (37087 > 32768). Running this sequence through the model will result in indexing errors
# 100% 200/200 [19:47<00:00,  5.94s/it]

# %%
# !python benchmark/eval.py --dir_path benchmark/longbench-result
# Out:
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:44: SyntaxWarning: invalid escape sequence '\.'
#   re_han_default = re.compile("([\u4E00-\u9FD5a-zA-Z0-9+#&\._%\-]+)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/__init__.py:46: SyntaxWarning: invalid escape sequence '\s'
#   re_skip_default = re.compile("(\r\n|\s)", re.U)
# /usr/local/lib/python3.12/dist-packages/jieba/finalseg/__init__.py:78: SyntaxWarning: invalid escape sequence '\.'
#   re_skip = re.compile("([a-zA-Z0-9]+(?:\.\d+)?%?)")
# /usr/local/lib/python3.12/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Evaluating on: ['narrativeqa.jsonl']
# {'narrativeqa': 10.92}

# %%
# new
# !python benchmark/pred.py \
--config_path config/qwen-small-origin.yaml \
--output_dir_path benchmark/longbench-result \
--datasets "multifieldqa_en,\
hotpotqa,2wikimqa,qasper,musique,narrativeqa"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Pred multifieldqa_en
#   0% 0/150 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/content/benchmark/pred.py", line 336, in <module>
#     preds = get_pred(
#             ^^^^^^^^^
#   File "/content/benchmark/pred.py", line 265, in get_pred
#     output = searcher.generate(
#              ^^^^^^^^^^^^^^^^^^
#   File "/content/inf_llm/utils/greedy_search.py", line 32, in generate
#     result = self._decode(input_ids, **kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/inf_llm/utils/greedy_search.py", line 54, in _decode
#     out = self.model(
#           ^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1775, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# ## Inf-LLM-16 Model Prediction Generations

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-infllm.yaml \
--output_dir_path benchmark/longbench-result \
--datasets "trec,triviaqa,samsum,\
passage_count,passage_retrieval_en"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Pred trec
# 100% 200/200 [19:39<00:00,  5.90s/it]
# Complete Pred trec
# Pred triviaqa
# 100% 200/200 [14:50<00:00,  4.45s/it]
# Complete Pred triviaqa
# Pred samsum
# 100% 200/200 [25:50<00:00,  7.75s/it]
# Complete Pred samsum
# Pred passage_count
# 100% 200/200 [09:10<00:00,  2.75s/it]
# Complete Pred passage_count
# Pred passage_retrieval_en
# 100% 200/200 [08:10<00:00,  2.45s/it]
# Complete Pred passage_retrieval_en

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-infllm.yaml \
--output_dir_path benchmark/longbench-result \
--datasets "lcc,repobench-p,\
gov_report,qmsum,multi_news"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Pred lcc
# 100% 500/500 [38:57<00:00,  4.67s/it]
# Complete Pred lcc
# Pred repobench-p
#  45% 224/500 [24:45<32:03,  6.97s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (34855 > 32768). Running this sequence through the model will result in indexing errors
# 100% 500/500 [55:45<00:00,  6.69s/it]
# Complete Pred repobench-p
# Pred gov_report
#  12% 25/200 [12:46<1:12:13, 24.76s/it]Exception ignored in: <generator object tqdm.__iter__ at 0x7e33d9af3640>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1196, in __iter__
#     self.close()
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 1275, in close
#     self._decr_instances(self)
#   File "/usr/local/lib/python3.12/dist-packages/tqdm/std.py", line 698, in _decr_instances
# ...

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-infllm.yaml \
--output_dir_path benchmark/longbench-result \
--datasets "2wikimqa,qmsum,multi_news,gov_report"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Pred 2wikimqa
# 100% 200/200 [06:31<00:00,  1.96s/it]
# Complete Pred 2wikimqa
# Pred qmsum
#  17% 34/200 [05:09<24:39,  8.91s/it]

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-infllm.yaml \
--output_dir_path benchmark/longbench-result \
--datasets "gov_report"
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# tokenizer_config.json: 1.29kB [00:00, 6.20MB/s]
# vocab.json: 2.78MB [00:00, 20.3MB/s]
# merges.txt: 1.67MB [00:00, 118MB/s]
# tokenizer.json: 7.03MB [00:00, 151MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 659/659 [00:00<00:00, 6.46MB/s]
# model.safetensors: 100% 988M/988M [00:01<00:00, 535MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 2.58MB/s]
# Pred gov_report
#  28% 56/200 [29:07<1:06:51, 27.86s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (41658 > 32768). Running this sequence through the model will result in indexing errors
# ...

# %% [markdown]
# ## Original Model Prediction Generations

# %%
# new
# !python benchmark/pred.py \
--config_path config/qwen-small-origin.yaml \
--output_dir_path benchmark/longbench-result \
--datasets "multifieldqa_en,qasper,\
hotpotqa,2wikimqa,musique,narrativeqa"
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# tokenizer_config.json: 1.29kB [00:00, 6.70MB/s]
# vocab.json: 2.78MB [00:00, 121MB/s]
# merges.txt: 1.67MB [00:00, 117MB/s]
# tokenizer.json: 7.03MB [00:00, 181MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 659/659 [00:00<00:00, 4.49MB/s]
# model.safetensors: 100% 988M/988M [00:04<00:00, 211MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 2.73MB/s]
# Pred multifieldqa_en
# 100% 150/150 [09:45<00:00,  3.90s/it]
# Complete Pred multifieldqa_en
# Pred qasper
# 100% 200/200 [13:56<00:00,  4.18s/it]
# Complete Pred qasper
# Pred hotpotqa
# 100% 200/200 [21:38<00:00,  6.49s/it]
# Complete Pred hotpotqa
# Pred 2wikimqa
# ...

# %%
# updated rag
# !python benchmark/pred.py \
--config_path config/qwen-small-origin.yaml \
--output_dir_path drive/MyDrive/nlp_result \
--datasets "multifieldqa_en,qasper,\
hotpotqa,2wikimqa,musique,narrativeqa"
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# tokenizer_config.json: 1.29kB [00:00, 7.28MB/s]
# vocab.json: 2.78MB [00:00, 128MB/s]
# merges.txt: 1.67MB [00:00, 129MB/s]
# tokenizer.json: 7.03MB [00:00, 178MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 659/659 [00:00<00:00, 5.86MB/s]
# model.safetensors: 100% 988M/988M [00:05<00:00, 192MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 2.46MB/s]
# Pred multifieldqa_en
# 100% 150/150 [10:53<00:00,  4.36s/it]
# Complete Pred multifieldqa_en
# Pred qasper
# 100% 200/200 [09:25<00:00,  2.83s/it]
# Complete Pred qasper
# Pred hotpotqa
# 100% 200/200 [31:03<00:00,  9.32s/it]
# Complete Pred hotpotqa
# Pred 2wikimqa
# ...

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-origin.yaml \
--output_dir_path drive/MyDrive/nlp_result \
--datasets "trec,triviaqa,samsum,\
passage_count,passage_retrieval_en"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Pred trec
# 100% 200/200 [17:35<00:00,  5.28s/it]
# Complete Pred trec
# Pred triviaqa
# 100% 200/200 [32:37<00:00,  9.79s/it]
# Complete Pred triviaqa
# Pred samsum
# 100% 200/200 [29:38<00:00,  8.89s/it]
# Complete Pred samsum
# Pred passage_count
# 100% 200/200 [39:28<00:00, 11.84s/it]
# Complete Pred passage_count
# Pred passage_retrieval_en
# 100% 200/200 [29:05<00:00,  8.73s/it]
# Complete Pred passage_retrieval_en

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-origin.yaml \
--output_dir_path drive/MyDrive/nlp_result \
--datasets "lcc,repobench-p,\
qmsum,multi_news,gov_report"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Pred lcc
# 100% 500/500 [28:37<00:00,  3.44s/it]
# Complete Pred lcc
# Pred repobench-p
#  45% 224/500 [36:00<52:36, 11.44s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (34855 > 32768). Running this sequence through the model will result in indexing errors
# 2025-12-05 09:28:58.655400: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-05 09:28:58.673514: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-origin.yaml \
--output_dir_path benchmark/longbench-result \
--datasets "qmsum,multi_news,lcc,repobench-p,gov_report"
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# tokenizer_config.json: 1.29kB [00:00, 6.02MB/s]
# vocab.json: 2.78MB [00:00, 129MB/s]
# merges.txt: 1.67MB [00:00, 136MB/s]
# tokenizer.json: 7.03MB [00:00, 177MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 659/659 [00:00<00:00, 5.93MB/s]
# model.safetensors: 100% 988M/988M [00:04<00:00, 198MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 1.43MB/s]
# Pred qmsum
# 100% 200/200 [1:06:10<00:00, 19.85s/it]
# Complete Pred qmsum
# Pred multi_news
# 100% 200/200 [33:36<00:00, 10.08s/it]
# Complete Pred multi_news
# Pred lcc
# 100% 500/500 [24:48<00:00,  2.98s/it]
# Complete Pred lcc
# Pred repobench-p
# ...

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-origin.yaml \
--output_dir_path benchmark/longbench-result \
--datasets "repobench-p,gov_report"
# Out:
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# tokenizer_config.json: 1.29kB [00:00, 7.19MB/s]
# vocab.json: 2.78MB [00:00, 118MB/s]
# merges.txt: 1.67MB [00:00, 127MB/s]
# tokenizer.json: 7.03MB [00:00, 172MB/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# config.json: 100% 659/659 [00:00<00:00, 6.71MB/s]
# model.safetensors: 100% 988M/988M [00:04<00:00, 229MB/s]
# generation_config.json: 100% 242/242 [00:00<00:00, 2.38MB/s]
# Pred repobench-p
#  45% 224/500 [24:46<35:30,  7.72s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (34855 > 32768). Running this sequence through the model will result in indexing errors
# ...

# %% [markdown]
# ## Retrieval-Only Model Prediction Generations

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-rag.yaml \
--output_dir_path drive/MyDrive/nlp_result/rag \
--datasets "trec,triviaqa,samsum,\
passage_count,passage_retrieval_en"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# number of tasks: 200
# Load Retrieved Context
# Pred trec
# is_inf False
# 100% 200/200 [09:30<00:00,  2.85s/it]
# Complete Pred trec
# number of tasks: 200
# Load Retrieved Context
# Pred triviaqa
# is_inf False
# 100% 200/200 [05:59<00:00,  1.80s/it]
# Complete Pred triviaqa
# number of tasks: 200
# Load Retrieved Context
# Pred samsum
# is_inf False
# 100% 200/200 [13:17<00:00,  3.99s/it]
# Complete Pred samsum
# number of tasks: 200
# Load Retrieved Context
# Pred passage_count
# is_inf False
# 100% 200/200 [01:37<00:00,  2.04it/s]
# Complete Pred passage_count
# number of tasks: 200
# Load Retrieved Context
# Pred passage_retrieval_en
# is_inf False
# 100% 200/200 [01:56<00:00,  1.71it/s]
# Complete Pred passage_retrieval_en

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-rag.yaml \
--output_dir_path drive/MyDrive/nlp_result/rag \
--datasets "multifieldqa_en,qasper,\
hotpotqa,2wikimqa,musique"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# number of tasks: 150
# Load Retrieved Context
# Pred multifieldqa_en
# is_inf False
# 100% 150/150 [03:49<00:00,  1.53s/it]
# Complete Pred multifieldqa_en
# number of tasks: 200
# Load Retrieved Context
# Pred qasper
# is_inf False
# 100% 200/200 [04:23<00:00,  1.32s/it]
# Complete Pred qasper
# number of tasks: 200
# Load Retrieved Context
# Pred hotpotqa
# is_inf False
# 100% 200/200 [02:26<00:00,  1.36it/s]
# Complete Pred hotpotqa
# number of tasks: 200
# Load Retrieved Context
# Pred 2wikimqa
# is_inf False
# 100% 200/200 [02:36<00:00,  1.28it/s]
# Complete Pred 2wikimqa
# number of tasks: 200
# Load Retrieved Context
# Pred musique
# is_inf False
# 100% 200/200 [02:39<00:00,  1.25it/s]
# Complete Pred musique

# %% [markdown]
# ## Retrieval-Inf Model Prediction Generations

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-retrvinf.yaml \
--output_dir_path drive/MyDrive/nlp_result/retrvinf \
--datasets "trec,triviaqa,samsum,\
passage_count,passage_retrieval_en"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# number of tasks: 200
# Load Retrieved Context
# Pred trec
# is_inf True
# 100% 200/200 [21:44<00:00,  6.52s/it]
# Complete Pred trec
# number of tasks: 200
# Load Retrieved Context
# Pred triviaqa
# is_inf True
# 100% 200/200 [18:49<00:00,  5.65s/it]
# Complete Pred triviaqa
# number of tasks: 200
# Load Retrieved Context
# Pred samsum
# is_inf True
# 100% 200/200 [31:32<00:00,  9.46s/it]
# Complete Pred samsum
# number of tasks: 200
# Load Retrieved Context
# Pred passage_count
# is_inf True
# 100% 200/200 [14:19<00:00,  4.30s/it]
# Complete Pred passage_count
# number of tasks: 200
# Load Retrieved Context
# Pred passage_retrieval_en
# is_inf True
# 100% 200/200 [12:17<00:00,  3.69s/it]
# Complete Pred passage_retrieval_en

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-retrvinf.yaml \
--output_dir_path drive/MyDrive/nlp_result/retrvinf \
--datasets "multifieldqa_en,qasper,\
hotpotqa,2wikimqa,musique"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# number of tasks: 150
# Load Retrieved Context
# Pred multifieldqa_en
# is_inf True
# 100% 150/150 [10:03<00:00,  4.03s/it]
# Complete Pred multifieldqa_en
# number of tasks: 200
# Load Retrieved Context
# Pred qasper
# is_inf True
# 100% 200/200 [11:08<00:00,  3.34s/it]
# Complete Pred qasper
# number of tasks: 200
# Load Retrieved Context
# Pred hotpotqa
# is_inf True
# 100% 200/200 [13:19<00:00,  4.00s/it]
# Complete Pred hotpotqa
# number of tasks: 200
# Load Retrieved Context
# Pred 2wikimqa
# is_inf True
# 100% 200/200 [08:02<00:00,  2.41s/it]
# Complete Pred 2wikimqa
# number of tasks: 200
# Load Retrieved Context
# Pred musique
# is_inf True
# 100% 200/200 [16:04<00:00,  4.82s/it]
# Complete Pred musique

# %% [markdown]
# ## Inf-LLM-24 Model Prediction Generations

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-infllm-longer.yaml \
--output_dir_path drive/MyDrive/nlp_result/infllm \
--datasets "2wikimqa,multifieldqa_en,qasper,\
hotpotqa,musique,narrativeqa"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# number of tasks: 200
# Pred 2wikimqa
# is_inf True
# 100% 200/200 [07:22<00:00,  2.21s/it]
# Complete Pred 2wikimqa
# number of tasks: 150
# Pred multifieldqa_en
# is_inf True
# 100% 150/150 [09:24<00:00,  3.76s/it]
# Complete Pred multifieldqa_en
# number of tasks: 200
# Pred qasper
# is_inf True
# 100% 200/200 [08:50<00:00,  2.65s/it]
# Complete Pred qasper
# number of tasks: 200
# Pred hotpotqa
# is_inf True
# 100% 200/200 [12:56<00:00,  3.88s/it]
# Complete Pred hotpotqa
# number of tasks: 200
# Pred musique
# is_inf True
# 100% 200/200 [15:49<00:00,  4.75s/it]
# Complete Pred musique
# number of tasks: 200
# Pred narrativeqa
# is_inf True
#   2% 4/200 [00:25<16:40,  5.10s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (37087 > 32768). Running this sequence through the model will result in indexing errors
# ...

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-infllm-longer.yaml \
--output_dir_path drive/MyDrive/nlp_result/infllm \
--datasets "trec,triviaqa,samsum,\
passage_count,passage_retrieval_en"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# number of tasks: 200
# Pred trec
# is_inf True
# 100% 200/200 [21:12<00:00,  6.36s/it]
# Complete Pred trec
# number of tasks: 200
# Pred triviaqa
# is_inf True
# 100% 200/200 [18:30<00:00,  5.55s/it]
# Complete Pred triviaqa
# number of tasks: 200
# Pred samsum
# is_inf True
# 100% 200/200 [27:56<00:00,  8.38s/it]
# Complete Pred samsum
# number of tasks: 200
# Pred passage_count
# is_inf True
# 100% 200/200 [13:48<00:00,  4.14s/it]
# Complete Pred passage_count
# number of tasks: 200
# Pred passage_retrieval_en
# is_inf True
# 100% 200/200 [11:44<00:00,  3.52s/it]
# Complete Pred passage_retrieval_en

# %%
# !python benchmark/pred.py \
--config_path config/qwen-small-infllm-longer.yaml \
--output_dir_path drive/MyDrive/nlp_result/infllm \
--datasets "qmsum,multi_news,lcc,repobench-p,gov_report"
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# number of tasks: 200
# Pred qmsum
# is_inf True
# 100% 200/200 [41:09<00:00, 12.35s/it]
# Complete Pred qmsum
# number of tasks: 200
# Pred multi_news
# is_inf True
# 100% 200/200 [1:01:49<00:00, 18.55s/it]
# Complete Pred multi_news
# number of tasks: 500
# Pred lcc
# is_inf True
# 100% 500/500 [39:34<00:00,  4.75s/it]
# Complete Pred lcc
# number of tasks: 500
# Pred repobench-p
# is_inf True
#  45% 224/500 [28:33<38:41,  8.41s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (34855 > 32768). Running this sequence through the model will result in indexing errors
# 100% 500/500 [1:04:45<00:00,  7.77s/it]
# Complete Pred repobench-p
# number of tasks: 200
# Pred gov_report
# is_inf True
# 100% 200/200 [1:55:46<00:00, 34.73s/it]
# Complete Pred gov_report
